# %%
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, PointStruct

import openai
import pandas as pd

# %%
qdrant_client = QdrantClient(url="http://localhost:6333")

qdrant_client.create_collection(
    collection_name="job-postings-collection-02",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)
# Out:
# True

# %%
df = pd.read_csv("../data/fraud/fake_job_postings.csv")

# %%
def preprocess_data(row):
    text = f"""{row['title']} Company: {row['company_profile']} 
    Requirements: {row['requirements']}
    Benefits: {row['benefits']} 
    Education: {row['required_education']} 
    Salary: {row['salary_range']} 
    """
    return text
    
df['text'] = df.apply(preprocess_data,axis=1)

# %%
df_sample = df.sample(n=50, random_state=25)

# %%
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=[text],
        model=model,
    )
    return response.data[0].embedding

# %%
data_to_embed = df_sample["text"].tolist()
pointstructs = []
for i, data in enumerate(data_to_embed):
    embedding = get_embedding(data)
    pointstructs.append(
        PointStruct(
            id=i,
            vector=embedding,
            payload={"text": data},
        )
    )

# %%
qdrant_client.upsert(
    collection_name="job-postings-collection-02",
    wait=True,
    points=pointstructs,
)
# Out:
# UpdateResult(operation_id=0, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
import json

output_schema = {
    "type": "array",
    "items": {
        "type": "object",
        "properties": {
            "question": {
                "type": "string",
                "description": "Suggested question.",
            },
            "chunk_ids": {
                "type": "array",
                "items": {
                    "type": "integer",
                    "description": "Index of the chunk that could be used to answer the question.",
                },
            },
            "answer_example": {
                "type": "string",
                "description": "Suggested answer grounded in the context.",
            },
            "reasoning": {
                "type": "string",
                "description": "Reasoning why the question could be answered with the chunks.",
            },
        },
    },
}


SYSTEM_PROMPT = f"""
I am building a RAG application. I have a collection of 50 chunks of text.
The RAG application will act as a job network assistant that can answer questions about the job postings we have available and if they are fake or real.
I will provide all of the available postings to you with indexes of each chunk.
I want you to come up with 30 questions to which the answers could be grounded in the chunk context.
As an output I need you to provide me the list of questions and the indexes of the chunks that could be used to answer them.
Also, provide an example answer to the question given the context of the chunks.
Also, provide the reason why you chose the chunks to answer the questions.
Try to have a mix of questions that could use multipple chunks and questions that could use single chunk.
Also, include 5 questions that can't be answered with the available chunks.


{json.dumps(output_schema, indent=2)}


I need to be able to parse the json output.
"""

USER_PROMPT = f"""
Here is the list of chunks, each list element is a dictionary with id and text:
{[{"id": i, "text": data} for i, data in enumerate(data_to_embed)]}
"""

# %%
response = openai.chat.completions.create(
    model="gpt-4.1",
    messages=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": USER_PROMPT}
    ]
)

print(response.choices[0].message.content)
# Out:
# ```json
# [
#   {
#     "question": "What are the main responsibilities and benefits for the Sales Leader - Healthcare Veterans role at SpotSource Solutions LLC?",
#     "chunk_ids": [0],
#     "answer_example": "The Sales Leader - Healthcare Veterans at SpotSource Solutions LLC is responsible for contacting and networking with Veterans and healthcare referral sources, educating clients about pension benefits and the VetAssist program, assisting with government benefit applications, conducting in-services, attending meetings, managing sales contacts via CRM, and completing administrative duties. Benefits include gas reimbursement for travel.",
#     "reasoning": "All job-specific responsibilities, benefits, and some background information are present in chunk 0."
#   },
#   {
#     "question": "What qualifications are required to apply for the Collections Supervisor position at Tidewater Finance Co.?",
#     "chunk_ids": [2],
#     "answer_example": "The position requires five years of collection experience, with at least two years in a leadership role, a college degree is preferred, and the candidate must have strong compliance/collection regulation knowledge, and experience with automated dialer systems.",
#     "reasoning": "All requirements are explicitly listed in the requirements section in chunk 2."
#   },
#   {
#     "question": "What benefits are offered for the Collections Supervisor position at Tidewater Finance Co.?",
#     "chunk_ids": [2],
#     "answer_example": "Benefits include vacation hours (40 after 6 months, 80 after 1 year), paid holidays, paid personal and sick leave, health, dental, life, and disability insurance, a 401k plan with company match, incentive bonuses, and differential pay for bilingual Spanish.",
#     "reasoning": "Benefits are directly described in chunk 2."
#   },
#   {
#     "question": "Is a degree required to teach English abroad with 'We help teachers get safe & secure jobs abroad'?",
#     "chunk_ids": [3, 11],
#     "answer_example": "Yes, a university degree (Bachelor's) is required to teach English abroad with this organization.",
#     "reasoning": "Both chunks mention the university degree as a requirement."
#   },
#   {
#     "question": "Which job postings mention background checks as part of their hiring process?",
#     "chunk_ids": [7, 21, 37],
#     "answer_example": "The Handyman & Independent Contractors (Home Pros) and PT Qualified Intellectual Disabilities Professional jobs indicate that background checks are conducted. The Call Center Representatives role also mentions a background check as part of the process.",
#     "reasoning": "All referenced chunks contain mention of background or security checks."
#   },
#   {
#     "question": "What are the desired technical skills for the Mobile Developer at schooX?",
#     "chunk_ids": [6],
#     "answer_example": "Experience with iOS, Objective C, or Cocoa Touch, proficiency in at least one modern OO language like Objective C, C++, or C#, experience with Git, MySQL, XML, JSON, and Web Services, and a good command of English are desired.",
#     "reasoning": "Technical requirements are detailed under 'Requirements' in chunk 6."
#   },
#   {
#     "question": "What job postings require a Bachelor's degree as a minimum education qualification?",
#     "chunk_ids": [3, 8, 11, 14, 15, 23, 34, 39, 41, 45, 46],
#     "answer_example": "Several jobs require at least a Bachelor’s Degree, including English Teacher Abroad, Business Development/Sales (Full Time), Project Manager (Fundnation), ServiceNow Solutions Engineer, Front-End Web Engineer (EatAds), Executive Assistant, Head of Partnerships (Axonix), User Experience and Interaction Designer, and National Sales Manager.",
#     "reasoning": "These postings mention 'Bachelor's Degree' or equivalent as a minimum requirement."
#   },
#   {
#     "question": "What positions are offered by companies specializing in IT, Engineering, and Manufacturing recruitment?",
#     "chunk_ids": [1, 13, 26, 30],
#     "answer_example": "Companies offering roles like Talent Management Process Manager, Electrical Supervisor, SAP Business Intelligence (Washington), and Operations Supervisor (Urbana, IL) specialize in recruiting for IT, Engineering, and Manufacturing jobs.",
#     "reasoning": "Chunks identify companies advertising for these sectors and positions."
#   },
#   {
#     "question": "What are the typical benefits provided by Novitex Enterprise Solutions to its employees?",
#     "chunk_ids": [10, 25, 42],
#     "answer_example": "Novitex provides a variety of roles such as Lobby Ambassador, Customer Service Technical Specialist, and Driver I. While not all postings specify full benefits, the company history suggests a focus on innovative solutions and employee support.",
#     "reasoning": "Chunks collectively provide the roles and hint at an employee-supportive culture, though explicit benefits are thin."
#   },
#   {
#     "question": "Which roles mention working with patients or individuals with disabilities?",
#     "chunk_ids": [0, 21],
#     "answer_example": "The Sales Leader at SpotSource Solutions (Healthcare Veterans) and the PT Qualified Intellectual Disabilities Professional both involve working with patients or individuals with disabilities.",
#     "reasoning": "Chunks detail direct interaction with these groups."
#   },
#   {
#     "question": "Which job roles explicitly require overseas or international travel?",
#     "chunk_ids": [9, 46, 12],
#     "answer_example": "The Java Integration Architect mentions travel up to 20-30%. The National Sales Manager requires heavy travel throughout the country of operation. The HAAD/DHA Licensed Doctors Opening is based in the UAE, implying need for relocation or international applicants.",
#     "reasoning": "Travel or relocation requirements are clear in the listed requirements."
#   },
#   {
#     "question": "What executive-level positions are posted and what are their key requirements?",
#     "chunk_ids": [43, 39, 34],
#     "answer_example": "Executive roles include Chief Financial Officer (12+ years relevant experience, Master’s degree preferred), Head of Partnerships (business development background, industry experience, Bachelor’s required), and Executive Assistant (experience as Executive/Personal Assistant, Bachelor’s degree).",
#     "reasoning": "Chunks contain detailed postings for executive and assistant roles."
#   },
#   {
#     "question": "What qualifications are required for the Construction Analyst (Safety) position at Middle East Recruitment?",
#     "chunk_ids": [49],
#     "answer_example": "A BS degree in engineering with at least 6 years’ experience, or B. Tech with 8+ years, or High School Diploma with 10+ years. OSHA certification within the last 5 years is required, among other safety and technical knowledge requirements.",
#     "reasoning": "The chunk provides a detailed list of qualifications."
#   },
#   {
#     "question": "Are there any positions where experience in pharmaceutical companies is needed?",
#     "chunk_ids": [27, 48],
#     "answer_example": "Yes, the Electrical Supervisor role requires experience in a pharmaceutical company, while the Accounts Payable Clerk experience within a pharmaceutical or manufacturing company is preferred.",
#     "reasoning": "Both specify pharmaceutical company work experience."
#   },
#   {
#     "question": "What jobs specifically mention support or advancement for veterans?",
#     "chunk_ids": [0, 48],
#     "answer_example": "The Sales Leader - Healthcare Veterans at SpotSource Solutions and Accounts Payable Clerk at Valor Services both refer to supporting or advancing veterans’ careers.",
#     "reasoning": "Chunks mention veterans as target applicant group or focus."
#   },
#   {
#     "question": "What postings indicate the availability of remote or work from home options?",
#     "chunk_ids": [35, 18, 47],
#     "answer_example": "The Data Scientist role at Red Canary and the Web Developer (Intern) position mention remote work. The Japanese Data Analyst job also offers a flexible work policy, including work from home.",
#     "reasoning": "Explicit or strongly implied remote option in these postings."
#   },
#   {
#     "question": "Which positions offer financial benefits such as 401(k) matching or profit sharing?",
#     "chunk_ids": [2, 15, 43],
#     "answer_example": "The Collections Supervisor (Tidewater Finance Co.) has a 401k with company match. ServiceNow Solutions Engineer (Virteva) offers a 401(k) with employer contribution. The Chief Financial Officer (Cequens) has profit share and other allowances.",
#     "reasoning": "Directly stated in the chunks’ benefits sections."
#   },
#   {
#     "question": "For which positions is knowledge of Adobe Creative Suite listed as a requirement?",
#     "chunk_ids": [32, 41, 45],
#     "answer_example": "Senior UI Engineer, UX Designer, and User Experience and Interaction Designer all require knowledge of Adobe Creative Suite, including Photoshop and Illustrator.",
#     "reasoning": "Requirements explicitly include Adobe tools."
#   },
#   {
#     "question": "What are the responsibilities for the PT Qualified Intellectual Disabilities Professional (QIDP)?",
#     "chunk_ids": [21],
#     "answer_example": "Responsibilities include writing program plans, supervising, providing habilitation for individuals with developmental disabilities, ensuring a safe environment, and handling stressful situations, among others.",
#     "reasoning": "A thorough responsibility section is detailed in chunk 21."
#   },
#   {
#     "question": "What positions mention language skills or needing to be bilingual?",
#     "chunk_ids": [2, 8, 17],
#     "answer_example": "Collections Supervisor offers pay differential for Spanish speakers. Business Development/Sales role mentions Hebrew as a plus. Android Developer lists language requirements in Greek.",
#     "reasoning": "Chunks reference specific or general language proficiency/bilingualism."
#   },
#   {
#     "question": "Which jobs work directly with sleep health or sleep lab software?",
#     "chunk_ids": [24],
#     "answer_example": "The Training Specialist - Somnoware position requires experience in the sleep industry and with sleep lab software.",
#     "reasoning": "Somnoware is a sleep wellness platform so the role is clearly connected."
#   },
#   {
#     "question": "What are the salary ranges for jobs that specify a range?",
#     "chunk_ids": [0, 8, 19, 34, 43, 46, 47, 49],
#     "answer_example": "Salaries mentioned: Sales Leader - Healthcare Veterans ($40,000-50,000), Business Development/Sales ($30,000-60,000), Account Representative ($50,000-58,000), Executive Assistant ($60,000-70,000), Chief Financial Officer ($300,000-450,000), National Sales Manager (800,000,000-1,200,000,000 — likely in non-USD currency), Japanese Data Analyst (£30,000-35,000), Construction Analyst (Safety) ($150,000-160,000).",
#     "reasoning": "Chunks include salary data where provided."
#   },
#   {
#     "question": "Which job postings are most clearly likely to be real, according to the provided information?",
#     "chunk_ids": [2, 9, 37, 19, 0],
#     "answer_example": "Collections Supervisor (Tidewater Finance Co.), Java Integration Architect (Backbase), Call Center Representatives (Stokes Automotive Group), Account Representative (healthcare), and Sales Leader (Healthcare Veterans) are likely real due to detailed descriptions, company history, and verifiable contact or website information.",
#     "reasoning": "These postings are detailed, reference established companies, and often provide contact or validation."
#   },
#   {
#     "question": "Which jobs seem potentially fake due to missing details or red flags?",
#     "chunk_ids": [5, 28, 31, 38, 44],
#     "answer_example": "Technical Writer 2, Beauty & Fragrance Consultants, Night Baker, Customer Service Representative (Hawkeye Recruitment), and BDC Agent lack important details such as requirements, company website, or a salary, making them seem potentially fake.",
#     "reasoning": "Chunks are vague, missing company info, or lacking typical job details."
#   },
#   {
#     "question": "Which postings specifically target recent graduates for employment?",
#     "chunk_ids": [11, 18],
#     "answer_example": "Graduates: English Teacher Abroad (Conversational) and Web Developer (Intern) seek recent graduates or students.",
#     "reasoning": "Chunks specify 'Graduates' or student status."
#   },
#   {
#     "question": "What jobs require an Associate's degree or equivalent as a minimum?",
#     "chunk_ids": [19, 27, 49],
#     "answer_example": "Account Representative requires an Associate's Degree. Electrical Supervisor (for some paths) also accepts Diploma of Associate Engineer (DAE). Construction Analyst allows for High School Diploma with extended experience.",
#     "reasoning": "Educational requirements list these degrees specifically."
#   },
#   {
#     "question": "Which postings provide relocation assistance?",
#     "chunk_ids": [24],
#     "answer_example": "The Training Specialist – Somnoware job mentions relocation assistance is available.",
#     "reasoning": "Only chunk 24 overtly mentions this benefit."
#   },
#   {
#     "question": "Which jobs require knowledge of databases or SQL?",
#     "chunk_ids": [6, 23, 26, 47],
#     "answer_example": "Mobile Developer, Front-End Web Engineer (India role), SAP Business Intelligence (.NET UNIX SQL), and Japanese Data Analyst all require or prefer skills in databases or SQL.",
#     "reasoning": "Requirements specify SQL, MySQL, or database knowledge."
#   },
#   {
#     "question": "What positions specifically mention working in a team or collaborative environment?",
#     "chunk_ids": [10, 25, 23, 41, 39, 47],
#     "answer_example": "Lobby Ambassador, Customer Service Technical Specialist, Front-End Web Engineer, UX Designer, Head of Partnerships, and Japanese Data Analyst all require teamwork or collaboration skills.",
#     "reasoning": "Requirements highlight working in teams or cross-functional collaboration."
#   },
#
#   // Five unanswerable questions below
#
#   {
#     "question": "What is the official company mailing address for the National Sales Manager position?",
#     "chunk_ids": [],
#     "answer_example": "This information is not available in the provided chunks.",
#     "reasoning": "No company address is stated for this posting."
#   },
#   {
#     "question": "Do any postings describe the process for employee promotions or internal mobility?",
#     "chunk_ids": [],
#     "answer_example": "There is no explicit information about promotion or internal mobility processes.",
#     "reasoning": "Promotion/internal mobility is not covered in the chunk details."
#   },
#   {
#     "question": "Which jobs include stock options as part of their compensation?",
#     "chunk_ids": [],
#     "answer_example": "No job postings mention the availability of stock options.",
#     "reasoning": "Stock options are not referenced in any chunk."
#   },
#   {
#     "question": "Which postings indicate the possibility of international transfer within the company?",
#     "chunk_ids": [],
#     "answer_example": "No jobs explicitly mention the opportunity for international transfer.",
#     "reasoning": "No explicit reference to international transfer processes."
#   },
#   {
#     "question": "Do any of the jobs offer paid parental leave?",
#     "chunk_ids": [],
#     "answer_example": "None of the job postings specify paid parental leave as a benefit.",
#     "reasoning": "No benefit section references paid parental leave."
#   }
# ]
# ```

# %%
import json

json_output = response.choices[0].message.content
json_output = json_output.replace("```json", "")
json_output = json_output.replace("```", "")
json_output = json_output.replace("// Five unanswerable questions below", "")
json_output = json.loads(json_output)

# %%
from langsmith import Client
import os

client = Client(api_key=os.environ["LANGSMITH_API_KEY"])

dataset_name = "rag-evaluation-job-posting-dataset"
dataset = client.create_dataset(
    dataset_name=dataset_name,
    description="Dataset for evaluating RAG pipeline"
)

# %%
for item in json_output:
    client.create_example(
        dataset_id=dataset.id,
        inputs={"question": item["question"]},
        outputs={
            "ground_truth": item["answer_example"],
            "context_ids": item["chunk_ids"],
            "contexts": [qdrant_client.retrieve(collection_name="job-postings-collection-02", ids=[id], with_payload=True)[0].payload["text"] for id in item["chunk_ids"]]
        }
    )

# %%
evals_df = pd.DataFrame(json_output)

# %%
evals_df.head()
# Out:
#                                             question    chunk_ids  \
# 0  What are the main responsibilities and benefit...          [0]
# 1  What qualifications are required to apply for ...          [2]
# 2  What benefits are offered for the Collections ...          [2]
# 3  Is a degree required to teach English abroad w...      [3, 11]
# 4  Which job postings mention background checks a...  [7, 21, 37]
#
#                                       answer_example  \
# 0  The Sales Leader - Healthcare Veterans at Spot...
# 1  The position requires five years of collection...
# 2  Benefits include vacation hours (40 after 6 mo...
# 3  Yes, a university degree (Bachelor's) is requi...
# 4  The Handyman & Independent Contractors (Home P...
#
#                                            reasoning
# 0  All job-specific responsibilities, benefits, a...
# 1  All requirements are explicitly listed in the ...
# 2        Benefits are directly described in chunk 2.
# 3  Both chunks mention the university degree as a...
# 4  All referenced chunks contain mention of backg...

# %%
evals_df.to_csv("evals.csv",index=False)
