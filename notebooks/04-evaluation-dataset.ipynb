# %%
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, PointStruct

import openai
import pandas as pd

# %%
qdrant_client = QdrantClient(url="http://localhost:6333")

qdrant_client.create_collection(
    collection_name="job-postings-collection-02",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)
# Out:
# True

# %%
df = pd.read_csv("../data/fraud/fake_job_postings.csv")

# %%
def preprocess_data(row):
    text = f"""{row['title']} Company: {row['company_profile']} 
    Requirements: {row['requirements']}
    Benefits: {row['benefits']} 
    Education: {row['required_education']} 
    Salary: {row['salary_range']} 
    """
    return text
    
df['text'] = df.apply(preprocess_data,axis=1)

# %%
df_sample = df.sample(n=50, random_state=124)

# %%
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=[text],
        model=model,
    )
    return response.data[0].embedding

# %%
data_to_embed = df_sample["text"].tolist()
pointstructs = []
for i, data in enumerate(data_to_embed):
    embedding = get_embedding(data)
    pointstructs.append(
        PointStruct(
            id=i,
            vector=embedding,
            payload={"text": data},
        )
    )

# %%
qdrant_client.upsert(
    collection_name="job-postings-collection-02",
    wait=True,
    points=pointstructs,
)
# Out:
# UpdateResult(operation_id=0, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
import json

output_schema = {
    "type": "array",
    "items": {
        "type": "object",
        "properties": {
            "question": {
                "type": "string",
                "description": "Suggested question.",
            },
            "chunk_ids": {
                "type": "array",
                "items": {
                    "type": "integer",
                    "description": "Index of the chunk that could be used to answer the question.",
                },
            },
            "answer_example": {
                "type": "string",
                "description": "Suggested answer grounded in the context.",
            },
            "reasoning": {
                "type": "string",
                "description": "Reasoning why the question could be answered with the chunks.",
            },
        },
    },
}


SYSTEM_PROMPT = f"""
I am building a RAG application. I have a collection of 50 chunks of text.
The RAG application will act as a job network assistant that can examine whether a job posting is fake but can also answer questions about the job posting itself.
I will provide all of the available postings to you with indexes of each chunk.
I want you to come up with 30 questions to which the answers could be grounded in the chunk context.
As an output I need you to provide me the list of questions and the indexes of the chunks that could be used to answer them.
Also, provide an example answer to the question given the context of the chunks.
Also, provide the reason why you chose the chunks to answer the questions.
Try to have a mix of questions that could use multiple chunks and questions that could use single chunk.
Also, include 5 questions that cannot be answered with the available chunks.


{json.dumps(output_schema, indent=2)}


I need to be able to parse the json output.
"""

USER_PROMPT = f"""
Here is the list of chunks, each list element is a dictionary with id and text:
{[{"id": i, "text": data} for i, data in enumerate(data_to_embed)]}
"""

# %%
response = openai.chat.completions.create(
    model="gpt-4.1",
    messages=[
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user", "content": USER_PROMPT}
    ]
)

print(response.choices[0].message.content)
# Out:
# ```json
# [
#   {
#     "question": "What are the primary requirements to be hired as a Data Scientist at Zaius?",
#     "chunk_ids": [1],
#     "answer_example": "The primary requirements for a Data Scientist at Zaius include a Master's Degree or PhD in a technical field such as computer science, machine learning, or applied mathematics, 3+ years of experience in commercial or government settings, and practical knowledge of data mining techniques and the use of R, Matlab, or python.",
#     "reasoning": "Chunk 1 provides a detailed job description, including educational, professional, and technical requirements."
#   },
#   {
#     "question": "Which job postings offer a 401K pension plan as part of their benefits?",
#     "chunk_ids": [0, 1, 18, 33],
#     "answer_example": "The Sales Representative, Data Scientist at Zaius, Title Account Executive at Network Closing Services, and Systems Engineer III at E Squared C offer a 401K plan as part of their benefits.",
#     "reasoning": "Chunks 0, 1, 18, and 33 mention 401K plans in their benefits sections."
#   },
#   {
#     "question": "What is the salary range for the Data-Network Engineer role?",
#     "chunk_ids": [9],
#     "answer_example": "The salary for the Data-Network Engineer role is £70,000 to £90,000, tax-free.",
#     "reasoning": "Chunk 9 includes the salary range in the job description."
#   },
#   {
#     "question": "Which postings offer remote or telecommute work opportunities?",
#     "chunk_ids": [5],
#     "answer_example": "The Director of Growth position at InVision offers remote or telecommute work opportunities.",
#     "reasoning": "Chunk 5 specifies that the Director of Growth position is remote/telecommute."
#   },
#   {
#     "question": "Are there any positions that require proficiency in Microsoft Office (Word, Excel, PowerPoint, Outlook)?",
#     "chunk_ids": [0, 3, 12, 30],
#     "answer_example": "The Sales Representative, Operations Paid Intern, Restaurant Manager, and Technology Manager roles require proficiency in various Microsoft Office applications.",
#     "reasoning": "These chunks explicitly mention Microsoft Office skills in the requirements."
#   },
#   {
#     "question": "Which jobs mention opportunities for relocation or relocation assistance?",
#     "chunk_ids": [7, 33],
#     "answer_example": "The Ruby Web Application Developer at Eagle mentions willingness to relocate as a plus. The Systems Engineer III role at E Squared C offers relocation assistance.",
#     "reasoning": "Chunk 7 describes willingness to relocate, and chunk 33 mentions relocation assistance as a benefit."
#   },
#   {
#     "question": "How do the company cultures differ at Aviary and The Beans Group?",
#     "chunk_ids": [4, 29],
#     "answer_example": "Aviary emphasizes a creative, team-driven startup culture with perks like ping-pong tables, free meals, and ongoing learning. The Beans Group fosters a rewarding, entrepreneurial culture with self-funded security, training, and fun amenities like table foosball.",
#     "reasoning": "Both chunks give detailed descriptions of their respective company cultures and values."
#   },
#   {
#     "question": "Which postings indicate award-winning companies?",
#     "chunk_ids": [12, 21, 29],
#     "answer_example": "Le Meridien Kuala Lumpur has won the 2013 Best Business Hotel Excellence Award. The Beans Group received the Digital Business of the Year award in 2013.",
#     "reasoning": "Award mentions are found in the provided company backgrounds in these chunks."
#   },
#   {
#     "question": "What are the educational requirements for the Civil Construction Coordinator role?",
#     "chunk_ids": [27],
#     "answer_example": "A Bachelor’s degree from a four-year college/university in construction, engineering, or comparable technical field OR a minimum of 10 years of similar supervisory experience is required.",
#     "reasoning": "Chunk 27 lists the education/experience qualifications for this position."
#   },
#   {
#     "question": "Which job postings mention equity or stock options as part of the compensation?",
#     "chunk_ids": [1, 14],
#     "answer_example": "The Data Scientist position at Zaius and the Account Manager at WeDeliver mention stock options or equity as part of the compensation.",
#     "reasoning": "Equity and Employee Stock Option Plan are specifically mentioned in these chunks."
#   },
#   {
#     "question": "What are the minimum qualifications for the Driver - Medium Duty (Seattle) job?",
#     "chunk_ids": [11],
#     "answer_example": "Qualifications include a High School Diploma or GED, a valid Class B Driver's License, DOT Medical Certification, basic computer skills, ability to be certified as a forklift operator, at least five years of general driving experience, and 1-3 years of route delivery experience.",
#     "reasoning": "Chunk 11 details several minimum qualifications for this role."
#   },
#   {
#     "question": "Are there any roles that specify the need for advanced degrees (Master’s, PhD)?",
#     "chunk_ids": [1, 19, 32],
#     "answer_example": "The Data Scientist at Zaius expects a Master’s or PhD, Engagement Director at Upstream prefers an MBA, and Director of Sales at Infrascale requires an MBA from a Tier 1 institute.",
#     "reasoning": "Degree requirements are stated clearly in these job postings."
#   },
#   {
#     "question": "Which postings require client-facing skills?",
#     "chunk_ids": [4, 19, 25, 37],
#     "answer_example": "The Partner Manager at Aviary, Engagement Director at Upstream, Mail Processing Associate at Novitex, and Sales Executive at Dice require strong client-facing or customer service skills.",
#     "reasoning": "These jobs either explicitly mention client-facing skills or include client service in their key skills."
#   },
#   {
#     "question": "Which job offers a sign-on bonus?",
#     "chunk_ids": [18],
#     "answer_example": "The Title Account Executive position at Network Closing Services offers a sign-on bonus.",
#     "reasoning": "Chunk 18 states 'SIGN ON BONUS AVAILABLE' in the benefits."
#   },
#   {
#     "question": "Which job postings indicate flexible vacation policies?",
#     "chunk_ids": [14, 13],
#     "answer_example": "The Account Manager at WeDeliver and the Account Manager at WhatArmy both offer flexible vacation policies.",
#     "reasoning": "Both chunks describe flexible or unlimited vacation as a benefit."
#   },
#   {
#     "question": "Do any postings explicitly welcome fresh graduates or inexperienced applicants?",
#     "chunk_ids": [2],
#     "answer_example": "The Customer Support Executives position welcomes freshers to apply.",
#     "reasoning": "This chunk clearly mentions freshers and is ideal for entry-level applicants."
#   },
#   {
#     "question": "Which roles provide paid travel as a benefit?",
#     "chunk_ids": [48],
#     "answer_example": "The Sales Rep for AT&T Solutions Provider at Argenta Field Solutions offers paid travel as a benefit.",
#     "reasoning": "Paid travel is part of the benefits listed for this position."
#   },
#   {
#     "question": "Are there job postings offering full medical or health insurance?",
#     "chunk_ids": [0, 1, 9, 18, 33, 48, 44],
#     "answer_example": "Sales Representative, Data Scientist at Zaius, Data-Network Engineer, Title Account Executive, Systems Engineer III at E Squared C, Sales Rep at AT&T Solutions Provider, and Chief Financial Officer at S2scout offer health or medical insurance.",
#     "reasoning": "Each of these postings mentions health or medical insurance as a benefit."
#   },
#   {
#     "question": "Which position is specifically described as a paid internship?",
#     "chunk_ids": [3],
#     "answer_example": "The Operations Paid Intern at Learner Loci is a paid internship position.",
#     "reasoning": "Chunk 3 explicitly describes the intern role and shows compensation-related information."
#   },
#   {
#     "question": "Are there any jobs that mention the work location being in the mountains?",
#     "chunk_ids": [2],
#     "answer_example": "The Customer Support Executives job mentions a willingness to relocate to mountains, amidst green mountains.",
#     "reasoning": "Chunk 2 highlights working in a setting close to nature and mountains."
#   },
#   {
#     "question": "Which postings discuss company growth or rapid expansion prominently?",
#     "chunk_ids": [5, 29, 47, 46],
#     "answer_example": "InVision, The Beans Group, and Carlyle Financial discuss rapid company growth or expansion.",
#     "reasoning": "These postings elaborate on business growth or recent rapid hiring and expansion."
#   },
#   {
#     "question": "What benefits are offered to the Ruby Web Application Developer at Eagle?",
#     "chunk_ids": [7],
#     "answer_example": "Benefits include a competitive salary, 25 days holiday (rising to 28), pension, private medical cover, and an employee share option scheme.",
#     "reasoning": "Chunk 7 lists all of these benefits in detail."
#   },
#   {
#     "question": "Which jobs mention performance-based evaluation or advancement?",
#     "chunk_ids": [26, 6],
#     "answer_example": "The Sales and Marketing roles at LEI Home Enhancements and Senior Ruby on Rails Developer mention advancement based on individual merit and performance.",
#     "reasoning": "These positions reference evaluation or progression tied to performance."
#   },
#   {
#     "question": "Is there any job that provides a Macbook or the choice of computer as a perk?",
#     "chunk_ids": [6, 5],
#     "answer_example": "The Senior Ruby on Rails Developer is offered a Mac or PC, and the Director of Growth at InVision is provided with a Macbook Air.",
#     "reasoning": "These chunks explicitly mention offering hardware as a perk."
#   },
#   {
#     "question": "Which postings seek employees comfortable working in a fast-paced or startup environment?",
#     "chunk_ids": [4, 19, 5, 29],
#     "answer_example": "Aviary, Upstream, InVision, and The Beans Group seek employees who can thrive in fast-paced or startup settings.",
#     "reasoning": "Such work environments are specifically stated as requirements or cultural points."
#   },
#   {
#     "question": "What roles require knowledge or experience with Agile or Scrum methodologies?",
#     "chunk_ids": [6, 7, 39, 42],
#     "answer_example": "The Senior Ruby on Rails Developer, Ruby Web Application Developer, Data Modeler, and Scrum Master/Project Manager require Agile or Scrum experience.",
#     "reasoning": "All four roles list Agile methodologies or Scrum in their requirements."
#   },
#   {
#     "question": "What are the language requirements for the Engagement Director at Upstream?",
#     "chunk_ids": [19],
#     "answer_example": "Excellent communication skills in English, Spanish, and Italian are required.",
#     "reasoning": "Chunk 19 specifies language requirements in the job description."
#   },
#   {
#     "question": "Which jobs require or prefer possession of teaching credentials like TEFL, TESOL, or CELTA?",
#     "chunk_ids": [17, 23, 31, 43],
#     "answer_example": "The English Teacher Abroad postings prefer candidates with TEFL, TESOL, or CELTA credentials.",
#     "reasoning": "All four chunks list these teaching credentials as requirements or preferred qualifications."
#   },
#   {
#     "question": "Which postings mention car allowance as a benefit?",
#     "chunk_ids": [18, 35, 45],
#     "answer_example": "The Title Account Executive, Outside Sales | Design Consultant, and Entry Level Sales positions mention a car allowance as a benefit.",
#     "reasoning": "These postings list car allowance in their benefit sections."
#   },
#   {
#     "question": "Which jobs require legal eligibility to work in the United States?",
#     "chunk_ids": [33],
#     "answer_example": "The Systems Engineer III at E Squared C requires the candidate to be able to work in the United States without sponsorship.",
#     "reasoning": "Chunk 33 explicitly mentions legal eligibility to work in the US."
#   },
#   {
#     "question": "What are the requirements to become a Lua developer at Eviture?",
#     "chunk_ids": [49],
#     "answer_example": "Requirements include a Bachelor's Degree in Computer Science or equivalent, experience in game development, strong teamwork and multitasking skills, and passion for software development and OO Design.",
#     "reasoning": "Chunk 49 lists the qualifications and experience needed."
#   },
#   {
#     "question": "What are the long-term growth opportunities or career development prospects offered by Upstream?",
#     "chunk_ids": [19],
#     "answer_example": "Upstream offers international career development prospects, opportunities to learn and grow in a world-class business environment, and a variety of professional development resources.",
#     "reasoning": "Chunk 19 discusses career development and progression options."
#   },
#   {
#     "question": "What is the current company size of Aviary?",
#     "chunk_ids": [4],
#     "answer_example": "Aviary is a team of 25 people based in New York.",
#     "reasoning": "Chunk 4 directly states the company's current staffing level."
#   },
#   {
#     "question": "Is it possible to determine which jobs are fake by only using the provided chunk texts?",
#     "chunk_ids": [],
#     "answer_example": "It is not possible to definitively determine if a job is fake solely based on the chunk texts provided.",
#     "reasoning": "Job authenticity usually requires external validation or additional context not present in the postings."
#   },
#   {
#     "question": "Are any of these jobs located in South America?",
#     "chunk_ids": [],
#     "answer_example": "No, the chunk texts do not provide sufficient information to determine that any jobs are located in South America.",
#     "reasoning": "None of the job descriptions mention a South American location."
#   },
#   {
#     "question": "Which job postings specify the company's annual revenue?",
#     "chunk_ids": [],
#     "answer_example": "None of the provided chunks specify the companies' annual revenue.",
#     "reasoning": "No mention of annual revenue is found in any job posting."
#   },
#   {
#     "question": "Do any positions offer on-site childcare facilities?",
#     "chunk_ids": [29],
#     "answer_example": "The Internal Recruiter position at The Beans Group offers on-site childcare facilities.",
#     "reasoning": "Chunk 29 mentions on-site childcare as a benefit."
#   },
#   {
#     "question": "Which postings discuss their company’s market share percentage?",
#     "chunk_ids": [],
#     "answer_example": "None of the job postings mention their company's market share percentage.",
#     "reasoning": "Market share figures are not stated in any chunk."
#   }
# ]
# ```

# %%
import json

json_output = response.choices[0].message.content
json_output = json_output.replace("```json", "")
json_output = json_output.replace("```", "")
json_output = json_output.replace("// Five unanswerable questions below", "")
json_output = json.loads(json_output)

# %%
from langsmith import Client
import os

client = Client(api_key=os.environ["LANGSMITH_API_KEY"])

dataset_name = "rag-evaluation-job-posting-dataset"
dataset = client.create_dataset(
    dataset_name=dataset_name,
    description="Dataset for evaluating RAG pipeline"
)

# %%
for item in json_output:
    client.create_example(
        dataset_id=dataset.id,
        inputs={"question": item["question"]},
        outputs={
            "ground_truth": item["answer_example"],
            "context_ids": item["chunk_ids"],
            "contexts": [qdrant_client.retrieve(collection_name="job-postings-collection-02", ids=[id], with_payload=True)[0].payload["text"] for id in item["chunk_ids"]]
        }
    )

# %%
evals_df = pd.DataFrame(json_output)

# %%
evals_df.head(10)
# Out:
#                                             question       chunk_ids  \
# 0  What are the primary requirements to be hired ...             [1]
# 1  Which job postings offer a 401K pension plan a...  [0, 1, 18, 33]
# 2  What is the salary range for the Data-Network ...             [9]
# 3  Which postings offer remote or telecommute wor...             [5]
# 4  Are there any positions that require proficien...  [0, 3, 12, 30]
# 5  Which jobs mention opportunities for relocatio...         [7, 33]
# 6  How do the company cultures differ at Aviary a...         [4, 29]
# 7   Which postings indicate award-winning companies?    [12, 21, 29]
# 8  What are the educational requirements for the ...            [27]
# 9  Which job postings mention equity or stock opt...         [1, 14]
#
#                                       answer_example  \
# 0  The primary requirements for a Data Scientist ...
# 1  The Sales Representative, Data Scientist at Za...
# 2  The salary for the Data-Network Engineer role ...
# 3  The Director of Growth position at InVision of...
# 4  The Sales Representative, Operations Paid Inte...
# 5  The Ruby Web Application Developer at Eagle me...
# 6  Aviary emphasizes a creative, team-driven star...
# 7  Le Meridien Kuala Lumpur has won the 2013 Best...
# 8  A Bachelor’s degree from a four-year college/u...
# 9  The Data Scientist position at Zaius and the A...
#
#                                            reasoning
# 0  Chunk 1 provides a detailed job description, i...
# 1  Chunks 0, 1, 18, and 33 mention 401K plans in ...
# 2  Chunk 9 includes the salary range in the job d...
# 3  Chunk 5 specifies that the Director of Growth ...
# 4  These chunks explicitly mention Microsoft Offi...
# 5  Chunk 7 describes willingness to relocate, and...
# 6  Both chunks give detailed descriptions of thei...
# 7  Award mentions are found in the provided compa...
# 8  Chunk 27 lists the education/experience qualif...
# 9  Equity and Employee Stock Option Plan are spec...

# %%
evals_df.to_csv("evals.csv",index=False)
